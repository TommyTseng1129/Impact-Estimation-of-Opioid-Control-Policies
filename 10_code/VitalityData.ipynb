# %%
import pandas as pd

# Read in data. The last 15 lines are comments.
deaths_2003 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2003.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2003 = deaths_2003.drop(columns=["Notes"])

# %%
deaths_2003
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2003.0     2003.0
# 1        Baldwin County, AL         1003  2003.0     2003.0
# 2        Baldwin County, AL         1003  2003.0     2003.0
# 3        Baldwin County, AL         1003  2003.0     2003.0
# 4        Barbour County, AL         1005  2003.0     2003.0
# ...                     ...          ...     ...        ...
# 4082  Sweetwater County, WY        56037  2003.0     2003.0
# 4083       Teton County, WY        56039  2003.0     2003.0
# 4084       Uinta County, WY        56041  2003.0     2003.0
# 4085    Washakie County, WY        56043  2003.0     2003.0
# 4086      Weston County, WY        56045  2003.0     2003.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2003['County'].value_counts()
# Out:
# Los Angeles County, CA    6
# Dallas County, TX         6
# Wayne County, MI          6
# Tarrant County, TX        6
# Orange County, CA         6
#                          ..
# Sheridan County, KS       1
# Laclede County, MO        1
# Parmer County, TX         1
# McDowell County, NC       1
# Shelby County, AL         1
# Name: County, Length: 3107, dtype: int64

# %%
# Read in data. The last 15 lines are comments.
deaths_2004 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2004.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2004 = deaths_2004.drop(columns=["Notes"])

deaths_2004
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2004.0     2004.0
# 1        Baldwin County, AL         1003  2004.0     2004.0
# 2        Baldwin County, AL         1003  2004.0     2004.0
# 3        Baldwin County, AL         1003  2004.0     2004.0
# 4        Barbour County, AL         1005  2004.0     2004.0
# ...                     ...          ...     ...        ...
# 4130  Sweetwater County, WY        56037  2004.0     2004.0
# 4131       Teton County, WY        56039  2004.0     2004.0
# 4132       Uinta County, WY        56041  2004.0     2004.0
# 4133    Washakie County, WY        56043  2004.0     2004.0
# 4134      Weston County, WY        56045  2004.0     2004.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2005 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2005.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2005 = deaths_2005.drop(columns=["Notes"])

deaths_2005
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2005.0     2005.0
# 1        Baldwin County, AL         1003  2005.0     2005.0
# 2        Baldwin County, AL         1003  2005.0     2005.0
# 3        Baldwin County, AL         1003  2005.0     2005.0
# 4        Barbour County, AL         1005  2005.0     2005.0
# ...                     ...          ...     ...        ...
# 4197  Sweetwater County, WY        56037  2005.0     2005.0
# 4198       Teton County, WY        56039  2005.0     2005.0
# 4199       Uinta County, WY        56041  2005.0     2005.0
# 4200    Washakie County, WY        56043  2005.0     2005.0
# 4201      Weston County, WY        56045  2005.0     2005.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
# Read in data. The last 15 lines are comments.
deaths_2006 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2006.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2006 = deaths_2006.drop(columns=["Notes"])

deaths_2006
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2006.0     2006.0
# 1        Baldwin County, AL         1003  2006.0     2006.0
# 2        Baldwin County, AL         1003  2006.0     2006.0
# 3        Baldwin County, AL         1003  2006.0     2006.0
# 4        Barbour County, AL         1005  2006.0     2006.0
# ...                     ...          ...     ...        ...
# 4257  Sweetwater County, WY        56037  2006.0     2006.0
# 4258       Teton County, WY        56039  2006.0     2006.0
# 4259       Uinta County, WY        56041  2006.0     2006.0
# 4260    Washakie County, WY        56043  2006.0     2006.0
# 4261      Weston County, WY        56045  2006.0     2006.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2007 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2007.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2007 = deaths_2007.drop(columns=["Notes"])

deaths_2007
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2007.0     2007.0
# 1        Baldwin County, AL         1003  2007.0     2007.0
# 2        Baldwin County, AL         1003  2007.0     2007.0
# 3        Baldwin County, AL         1003  2007.0     2007.0
# 4        Barbour County, AL         1005  2007.0     2007.0
# ...                     ...          ...     ...        ...
# 4299  Sweetwater County, WY        56037  2007.0     2007.0
# 4300       Teton County, WY        56039  2007.0     2007.0
# 4301       Uinta County, WY        56041  2007.0     2007.0
# 4302    Washakie County, WY        56043  2007.0     2007.0
# 4303      Weston County, WY        56045  2007.0     2007.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
# Read in data. The last 15 lines are comments.
deaths_2008 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2008.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2008 = deaths_2008.drop(columns=["Notes"])

deaths_2008
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2008.0     2008.0
# 1        Baldwin County, AL         1003  2008.0     2008.0
# 2        Baldwin County, AL         1003  2008.0     2008.0
# 3        Baldwin County, AL         1003  2008.0     2008.0
# 4        Barbour County, AL         1005  2008.0     2008.0
# ...                     ...          ...     ...        ...
# 4364  Sweetwater County, WY        56037  2008.0     2008.0
# 4365       Teton County, WY        56039  2008.0     2008.0
# 4366       Uinta County, WY        56041  2008.0     2008.0
# 4367    Washakie County, WY        56043  2008.0     2008.0
# 4368      Weston County, WY        56045  2008.0     2008.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2009 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2009.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2009 = deaths_2009.drop(columns=["Notes"])

deaths_2009
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2009.0     2009.0
# 1        Baldwin County, AL         1003  2009.0     2009.0
# 2        Baldwin County, AL         1003  2009.0     2009.0
# 3        Barbour County, AL         1005  2009.0     2009.0
# 4           Bibb County, AL         1007  2009.0     2009.0
# ...                     ...          ...     ...        ...
# 4359  Sweetwater County, WY        56037  2009.0     2009.0
# 4360       Teton County, WY        56039  2009.0     2009.0
# 4361       Uinta County, WY        56041  2009.0     2009.0
# 4362    Washakie County, WY        56043  2009.0     2009.0
# 4363      Weston County, WY        56045  2009.0     2009.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2             All other non-drug and non-alcohol causes
# ...

# %%
deaths_2010 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2010.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2010 = deaths_2010.drop(columns=["Notes"])

deaths_2010
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2010.0     2010.0
# 1        Baldwin County, AL         1003  2010.0     2010.0
# 2        Baldwin County, AL         1003  2010.0     2010.0
# 3        Baldwin County, AL         1003  2010.0     2010.0
# 4        Barbour County, AL         1005  2010.0     2010.0
# ...                     ...          ...     ...        ...
# 4436  Sweetwater County, WY        56037  2010.0     2010.0
# 4437       Teton County, WY        56039  2010.0     2010.0
# 4438       Uinta County, WY        56041  2010.0     2010.0
# 4439    Washakie County, WY        56043  2010.0     2010.0
# 4440      Weston County, WY        56045  2010.0     2010.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2011 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2011.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2011 = deaths_2011.drop(columns=["Notes"])

deaths_2011
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2011.0     2011.0
# 1        Baldwin County, AL         1003  2011.0     2011.0
# 2        Baldwin County, AL         1003  2011.0     2011.0
# 3        Baldwin County, AL         1003  2011.0     2011.0
# 4        Barbour County, AL         1005  2011.0     2011.0
# ...                     ...          ...     ...        ...
# 4510  Sweetwater County, WY        56037  2011.0     2011.0
# 4511       Teton County, WY        56039  2011.0     2011.0
# 4512       Uinta County, WY        56041  2011.0     2011.0
# 4513    Washakie County, WY        56043  2011.0     2011.0
# 4514      Weston County, WY        56045  2011.0     2011.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2012 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2012.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2012 = deaths_2012.drop(columns=["Notes"])

deaths_2012
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2012.0     2012.0
# 1        Baldwin County, AL         1003  2012.0     2012.0
# 2        Baldwin County, AL         1003  2012.0     2012.0
# 3        Baldwin County, AL         1003  2012.0     2012.0
# 4        Barbour County, AL         1005  2012.0     2012.0
# ...                     ...          ...     ...        ...
# 4529  Sweetwater County, WY        56037  2012.0     2012.0
# 4530       Teton County, WY        56039  2012.0     2012.0
# 4531       Uinta County, WY        56041  2012.0     2012.0
# 4532    Washakie County, WY        56043  2012.0     2012.0
# 4533      Weston County, WY        56045  2012.0     2012.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2013 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2013.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2013 = deaths_2013.drop(columns=["Notes"])

deaths_2013
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2013.0     2013.0
# 1        Baldwin County, AL         1003  2013.0     2013.0
# 2        Baldwin County, AL         1003  2013.0     2013.0
# 3        Baldwin County, AL         1003  2013.0     2013.0
# 4        Barbour County, AL         1005  2013.0     2013.0
# ...                     ...          ...     ...        ...
# 4589  Sweetwater County, WY        56037  2013.0     2013.0
# 4590       Teton County, WY        56039  2013.0     2013.0
# 4591       Uinta County, WY        56041  2013.0     2013.0
# 4592    Washakie County, WY        56043  2013.0     2013.0
# 4593      Weston County, WY        56045  2013.0     2013.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2014 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2014.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2014 = deaths_2014.drop(columns=["Notes"])

deaths_2014
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2014.0     2014.0
# 1        Baldwin County, AL         1003  2014.0     2014.0
# 2        Baldwin County, AL         1003  2014.0     2014.0
# 3        Baldwin County, AL         1003  2014.0     2014.0
# 4        Barbour County, AL         1005  2014.0     2014.0
# ...                     ...          ...     ...        ...
# 4646  Sweetwater County, WY        56037  2014.0     2014.0
# 4647       Teton County, WY        56039  2014.0     2014.0
# 4648       Uinta County, WY        56041  2014.0     2014.0
# 4649    Washakie County, WY        56043  2014.0     2014.0
# 4650      Weston County, WY        56045  2014.0     2014.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
deaths_2015 = pd.read_csv(
    "/Users/caleboneel/Desktop/estimating-impact-of-opioids-2020-purlple-team/00_source/US_VitalStatistics/UnderlyingCauseofDeath2015.txt",
    sep="\t",
    skipfooter=15,
    engine="python",
)
# Drop the Notes column
deaths_2015 = deaths_2015.drop(columns=["Notes"])

deaths_2015
# Out:
#                      County  County Code    Year  Year Code  \
# 0        Autauga County, AL         1001  2015.0     2015.0
# 1        Baldwin County, AL         1003  2015.0     2015.0
# 2        Baldwin County, AL         1003  2015.0     2015.0
# 3        Baldwin County, AL         1003  2015.0     2015.0
# 4        Barbour County, AL         1005  2015.0     2015.0
# ...                     ...          ...     ...        ...
# 4778  Sweetwater County, WY        56037  2015.0     2015.0
# 4779       Teton County, WY        56039  2015.0     2015.0
# 4780       Uinta County, WY        56041  2015.0     2015.0
# 4781    Washakie County, WY        56043  2015.0     2015.0
# 4782      Weston County, WY        56045  2015.0     2015.0
#
#                              Drug/Alcohol Induced Cause  \
# 0             All other non-drug and non-alcohol causes
# 1     Drug poisonings (overdose) Unintentional (X40-...
# 2                      All other alcohol-induced causes
# ...

# %%
alleg = deaths_2015[deaths_2015['County'] == 'Alameda County, CA']
alleg
# Out:
#                  County  County Code    Year  Year Code  \
# 281  Alameda County, CA         6001  2015.0     2015.0
# 282  Alameda County, CA         6001  2015.0     2015.0
# 283  Alameda County, CA         6001  2015.0     2015.0
# 284  Alameda County, CA         6001  2015.0     2015.0
# 285  Alameda County, CA         6001  2015.0     2015.0
# 286  Alameda County, CA         6001  2015.0     2015.0
#
#                             Drug/Alcohol Induced Cause  \
# 281  Drug poisonings (overdose) Unintentional (X40-...
# 282       Drug poisonings (overdose) Suicide (X60-X64)
# 283                      All other drug-induced causes
# 284      Alcohol poisonings (overdose) (X45, X65, Y15)
# 285                   All other alcohol-induced causes
# 286          All other non-drug and non-alcohol causes
#
#     Drug/Alcohol Induced Cause Code Deaths
# 281                              D1    176
# 282                              D2     22
# 283                              D9     12
# ...

# %%
# Initialize a new data frame and stack the individual years  data sets on top of one another

vitality = pd.DataFrame()
vitality.shape[0]
# Out:
# 0

# %%
# Add asserts to make sure that the number of rows are added correctly and all data is put in the new dataframe

vitality = pd.concat([deaths_2003, deaths_2004], ignore_index = True)
assert vitality.shape[0] == (deaths_2003.shape[0] + deaths_2004.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2005], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2005.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2006], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2006.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2007], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2007.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2008], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2008.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2009], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2009.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2010], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2010.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2011], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2011.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2012], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2012.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2013], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2013.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2014], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2014.shape[0])

# %%
dfrows = vitality.shape[0]

vitality = pd.concat([vitality, deaths_2015], ignore_index = True)

assert vitality.shape[0] == (dfrows + deaths_2015.shape[0])

# %%
vitality
# Out:
#                       County  County Code    Year  Year Code  \
# 0         Autauga County, AL         1001  2003.0     2003.0
# 1         Baldwin County, AL         1003  2003.0     2003.0
# 2         Baldwin County, AL         1003  2003.0     2003.0
# 3         Baldwin County, AL         1003  2003.0     2003.0
# 4         Barbour County, AL         1005  2003.0     2003.0
# ...                      ...          ...     ...        ...
# 57236  Sweetwater County, WY        56037  2015.0     2015.0
# 57237       Teton County, WY        56039  2015.0     2015.0
# 57238       Uinta County, WY        56041  2015.0     2015.0
# 57239    Washakie County, WY        56043  2015.0     2015.0
# 57240      Weston County, WY        56045  2015.0     2015.0
#
#                               Drug/Alcohol Induced Cause  \
# 0              All other non-drug and non-alcohol causes
# 1      Drug poisonings (overdose) Unintentional (X40-...
# 2                       All other alcohol-induced causes
# ...

# %%
# Check that there is a reasonable number of rows for each year
tot_2015 = vitality[vitality['Year'] == 2015.0]
tot = tot_2015[tot_2015['County'] == 'Anne Arundel County, MD']
tot
# Out:
#                         County  County Code    Year  Year Code  \
# 54273  Anne Arundel County, MD        24003  2015.0     2015.0
# 54274  Anne Arundel County, MD        24003  2015.0     2015.0
# 54275  Anne Arundel County, MD        24003  2015.0     2015.0
# 54276  Anne Arundel County, MD        24003  2015.0     2015.0
# 54277  Anne Arundel County, MD        24003  2015.0     2015.0
#
#                               Drug/Alcohol Induced Cause  \
# 54273  Drug poisonings (overdose) Unintentional (X40-...
# 54274       Drug poisonings (overdose) Suicide (X60-X64)
# 54275  Drug poisonings (overdose) Undetermined (Y10-Y14)
# 54276                   All other alcohol-induced causes
# 54277          All other non-drug and non-alcohol causes
#
#       Drug/Alcohol Induced Cause Code Deaths
# 54273                              D1     34
# 54274                              D2     11
# 54275                              D4     88
# 54276                              A9     32
# ...

# %%
# Dropping all observations that do not have a cause of death related to drug overdose

drugCodes = ['D1', 'D2', 'D4', 'D9']
drug_vitality1 = vitality[vitality['Drug/Alcohol Induced Cause Code'].isin(drugCodes)]

drug_vitality1['Drug/Alcohol Induced Cause Code'].value_counts()
# Out:
# D1    7573
# D2    1465
# D4     761
# D9     628
# Name: Drug/Alcohol Induced Cause Code, dtype: int64

# %%
# Rename columns to make them less cumbersome
drug_vitality2 = drug_vitality1.copy()
drug_vitality2.rename(columns = {'Drug/Alcohol Induced Cause Code':'Death Code', 'Drug/Alcohol Induced Cause':'Cause of Death'}, inplace = True)

# %%
drug_vitality3 = drug_vitality2.copy()
drug_vitality3
# Out:
#                       County  County Code    Year  Year Code  \
# 1         Baldwin County, AL         1003  2003.0     2003.0
# 38      Jefferson County, AL         1073  2003.0     2003.0
# 39      Jefferson County, AL         1073  2003.0     2003.0
# 54         Mobile County, AL         1097  2003.0     2003.0
# 78     Anchorage Borough, AK         2020  2003.0     2003.0
# ...                      ...          ...     ...        ...
# 57202    Waukesha County, WI        55133  2015.0     2015.0
# 57208   Winnebago County, WI        55139  2015.0     2015.0
# 57218     Fremont County, WY        56013  2015.0     2015.0
# 57224     Laramie County, WY        56021  2015.0     2015.0
# 57228     Natrona County, WY        56025  2015.0     2015.0
#
#                                           Cause of Death Death Code Deaths
# 1      Drug poisonings (overdose) Unintentional (X40-...         D1     10
# 38     Drug poisonings (overdose) Unintentional (X40-...         D1     37
# ...

# %%
#Drog extraneous column "Year Code" which is the same as year, also drop the last line of data in the framew which is a wierd na/year value that was accidently added

drug_vitality3.drop(['Year Code'], axis=1, inplace = True)
#drug_vitality3.drop(drug_vitality.tail(1).index,inplace=True)

# %%
# Check the Data frame for Null values 

drug_vitality3['County'].isnull().values.any()
drug_vitality3['County Code'].isnull().values.any()
drug_vitality3['Year'].isnull().values.any()
drug_vitality3['Cause of Death'].isnull().values.any()
drug_vitality3['Death Code'].isnull().values.any()
drug_vitality3['Deaths'].isnull().values.any()
# Out:
# False

# %%
drug_vitality3[drug_vitality3['County Code'] == 24003]
# Out:
#                         County  County Code    Year  \
# 1571   Anne Arundel County, MD        24003  2003.0
# 5684   Anne Arundel County, MD        24003  2004.0
# 9853   Anne Arundel County, MD        24003  2005.0
# 14067  Anne Arundel County, MD        24003  2006.0
# 18343  Anne Arundel County, MD        24003  2007.0
# 22667  Anne Arundel County, MD        24003  2008.0
# 27054  Anne Arundel County, MD        24003  2009.0
# 27055  Anne Arundel County, MD        24003  2009.0
# 31435  Anne Arundel County, MD        24003  2010.0
# 31436  Anne Arundel County, MD        24003  2010.0
# 35881  Anne Arundel County, MD        24003  2011.0
# 40416  Anne Arundel County, MD        24003  2012.0
# 40417  Anne Arundel County, MD        24003  2012.0
# 44966  Anne Arundel County, MD        24003  2013.0
# 44967  Anne Arundel County, MD        24003  2013.0
# 44968  Anne Arundel County, MD        24003  2013.0
# 49585  Anne Arundel County, MD        24003  2014.0
# ...

# %%
# Create a copy of the final data set to create version with total deaths per county per year, not taking type of overdose into account
import numpy as np

od_deaths = drug_vitality3.copy()
od_deaths.replace('Missing', np.nan, inplace=True)
od_deaths['Deaths'] = od_deaths['Deaths'].astype(float)
#print(od_deaths.dtypes)

# %%
od_deaths
# Out:
#                       County  County Code    Year  \
# 1         Baldwin County, AL         1003  2003.0
# 38      Jefferson County, AL         1073  2003.0
# 39      Jefferson County, AL         1073  2003.0
# 54         Mobile County, AL         1097  2003.0
# 78     Anchorage Borough, AK         2020  2003.0
# ...                      ...          ...     ...
# 57202    Waukesha County, WI        55133  2015.0
# 57208   Winnebago County, WI        55139  2015.0
# 57218     Fremont County, WY        56013  2015.0
# 57224     Laramie County, WY        56021  2015.0
# 57228     Natrona County, WY        56025  2015.0
#
#                                           Cause of Death Death Code  Deaths
# 1      Drug poisonings (overdose) Unintentional (X40-...         D1    10.0
# 38     Drug poisonings (overdose) Unintentional (X40-...         D1    37.0
# 39                         All other drug-induced causes         D9    32.0
# ...

# %%
#Drop drug cause of death and code

od_deaths.drop(['Cause of Death', 'Death Code'], axis = 1, inplace = True)
od_deaths[od_deaths['County Code'] == 24003]
# Out:
#                         County  County Code    Year  Deaths
# 1571   Anne Arundel County, MD        24003  2003.0    41.0
# 5684   Anne Arundel County, MD        24003  2004.0    53.0
# 9853   Anne Arundel County, MD        24003  2005.0    58.0
# 14067  Anne Arundel County, MD        24003  2006.0    61.0
# 18343  Anne Arundel County, MD        24003  2007.0    68.0
# 22667  Anne Arundel County, MD        24003  2008.0    70.0
# 27054  Anne Arundel County, MD        24003  2009.0    10.0
# 27055  Anne Arundel County, MD        24003  2009.0    64.0
# 31435  Anne Arundel County, MD        24003  2010.0    10.0
# 31436  Anne Arundel County, MD        24003  2010.0    49.0
# 35881  Anne Arundel County, MD        24003  2011.0    72.0
# 40416  Anne Arundel County, MD        24003  2012.0    15.0
# 40417  Anne Arundel County, MD        24003  2012.0    60.0
# 44966  Anne Arundel County, MD        24003  2013.0    25.0
# 44967  Anne Arundel County, MD        24003  2013.0    11.0
# ...

# %%
#Groupby County and Year 

od_deaths = od_deaths.groupby(["County","County Code", "Year"], as_index = False).sum()

# %%
# Final Dataset

od_deaths['Year'].value_counts()
od_deaths[od_deaths['County Code'] == 24003]

#od_deaths['State'] = 
od_deaths_state = od_deaths['County'].str.split(pat=', ', n=1, expand=True)

# %%
od_deaths_state['County Code'] = od_deaths['County Code']
od_deaths_state['Year'] = od_deaths['Year']
od_deaths_state['Deaths'] = od_deaths['Deaths']

od_deaths_state
# Out:
#                   0   1  County Code    Year  Deaths
# 0     Acadia Parish  LA        22001  2003.0    11.0
# 1     Acadia Parish  LA        22001  2005.0    23.0
# 2     Acadia Parish  LA        22001  2006.0    19.0
# 3     Acadia Parish  LA        22001  2007.0    19.0
# 4     Acadia Parish  LA        22001  2009.0    11.0
# ...             ...  ..          ...     ...     ...
# 7920    Yuma County  AZ         4027  2011.0    20.0
# 7921    Yuma County  AZ         4027  2012.0    32.0
# 7922    Yuma County  AZ         4027  2013.0    22.0
# 7923    Yuma County  AZ         4027  2014.0    35.0
# 7924    Yuma County  AZ         4027  2015.0    24.0
#
# [7925 rows x 5 columns]

# %%
od_deaths_state.rename(columns = {0:'County', 1:'State'}, inplace = True) 
od_deaths_state
# Out:
#              County State  County Code    Year  Deaths
# 0     Acadia Parish    LA        22001  2003.0    11.0
# 1     Acadia Parish    LA        22001  2005.0    23.0
# 2     Acadia Parish    LA        22001  2006.0    19.0
# 3     Acadia Parish    LA        22001  2007.0    19.0
# 4     Acadia Parish    LA        22001  2009.0    11.0
# ...             ...   ...          ...     ...     ...
# 7920    Yuma County    AZ         4027  2011.0    20.0
# 7921    Yuma County    AZ         4027  2012.0    32.0
# 7922    Yuma County    AZ         4027  2013.0    22.0
# 7923    Yuma County    AZ         4027  2014.0    35.0
# 7924    Yuma County    AZ         4027  2015.0    24.0
#
# [7925 rows x 5 columns]

# %%
od_deaths.to_csv('od_deaths.csv', index=False)
od_deaths.to_csv('od_deaths.csv', index=False)
