# %%
import pandas as pd
import numpy as np

# %load_ext lab_black
# Out:
# The lab_black extension is already loaded. To reload it, use:
#   %reload_ext lab_black

# %%
# import data
od = pd.read_csv(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/final_drug_od_dataset.csv"
)

# import data

quant = pd.read_csv(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/drug_shipment_data.csv"
)

# %%
od[od.State == "Hawaii"]
# Out:
#        FIPS State Abbr           County    Year  Population  \
# 6760  15001         HI    Hawaii County  2003.0      158442
# 6761  15001         HI    Hawaii County  2004.0      162852
# 6762  15001         HI    Hawaii County  2005.0      168237
# 6763  15001         HI    Hawaii County  2006.0      173536
# 6764  15001         HI    Hawaii County  2007.0      177733
# 6765  15001         HI    Hawaii County  2008.0      181506
# 6766  15001         HI    Hawaii County  2009.0      183629
# 6767  15001         HI    Hawaii County  2010.0      185363
# 6768  15001         HI    Hawaii County  2011.0      187079
# 6769  15001         HI    Hawaii County  2012.0      189161
# 6770  15001         HI    Hawaii County  2013.0      191459
# 6771  15001         HI    Hawaii County  2014.0      193711
# 6772  15001         HI    Hawaii County  2015.0      195975
# 6773  15003         HI  Honolulu County  2003.0      894311
# 6774  15003         HI  Honolulu County  2004.0      907997
# ...

# %%
od_summary_table = od.describe()
od_summary_table.to_excel(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/overdose_summary_table.xlsx"
)

# %%
od = od.groupby(by="State").mean()
od.to_excel(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/overdose_summary_table2.xlsx"
)

# %%
od.sort_values("Deaths Per 100,000 People", ascending=False)
# Out:
#                               FIPS    Year     Population  \
# State
# West Virginia         54055.000000  2009.0   33443.551049
# Kentucky              21120.000000  2009.0   35819.364103
# New Mexico            35030.151515  2009.0   61111.351981
# Oklahoma              40077.000000  2009.0   48153.593407
# Nevada                32045.529412  2009.0  154338.950226
# Mississippi           28082.000000  2009.0   35932.380863
# Tennessee             47095.000000  2009.0   65913.225911
# Louisiana             22064.000000  2009.0   70804.909856
# Ohio                  39088.000000  2009.0  130949.440559
# District of Columbia  11001.000000  2009.0  605323.076923
# Rhode Island          44005.000000  2009.0  211880.123077
# Wyoming               56023.000000  2009.0   23908.060201
# Missouri              29117.713043  2009.0   51546.507692
# Pennsylvania          42067.000000  2009.0  188476.234214
# Indiana               18092.000000  2009.0   69916.473244
# ...

# %%
quant
# Out:
#       Unnamed: 0 State Abbr      State          County   FIPS    Year  \
# 0              0         AL    Alabama  Autauga County   1001  2006.0
# 1              1         AL    Alabama  Autauga County   1001  2007.0
# 2              2         AL    Alabama  Autauga County   1001  2008.0
# 3              3         AL    Alabama  Autauga County   1001  2009.0
# 4              4         AL    Alabama  Autauga County   1001  2010.0
# ...          ...        ...        ...             ...    ...     ...
# 3543        3543         TN  Tennessee   Wilson County  47189  2008.0
# 3544        3544         TN  Tennessee   Wilson County  47189  2009.0
# 3545        3545         TN  Tennessee   Wilson County  47189  2010.0
# 3546        3546         TN  Tennessee   Wilson County  47189  2011.0
# 3547        3547         TN  Tennessee   Wilson County  47189  2012.0
#
#       Total_Weight  Population  PerCapWeight
# 0     17100.542225       51328  33316.206018
# ...

# %%
quant_summary_table = quant.describe()
quant_summary_table.to_excel(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/drug_shipment_summary_table.xlsx"
)

# %%
quant = quant.groupby(by="State").mean()
quant.to_excel(
    "/Users/samsloate/Desktop/Data_Science/Opioids_Project/estimating-impact-of-opioids-2020-purlple-team/20_intermediate_files/drug_shipment_summary_table2.xlsx"
)

# %%
quant
# Out:
#                 Unnamed: 0          FIPS         Year   Total_Weight  \
# State
# Alabama              234.0   1067.000000  2009.000000   30448.494137
# Florida              701.5  12068.070815  2009.012876  190876.400802
# Georgia             1466.0  13160.984948  2008.990593   19993.068933
# Mississippi         2281.0  28082.333333  2009.000000   11372.962369
# South Carolina      2725.5  45046.000000  2009.000000   43054.551574
# Tennessee           3217.0  47094.515885  2009.009077   40088.279415
#
#                    Population  PerCapWeight
# State
# Alabama          70742.130064  37513.630673
# Florida         280845.431330  51939.784566
# Georgia          62860.278457  34804.210235
# Mississippi      36442.095238  27607.279362
# South Carolina   99210.627329  34608.497302
# Tennessee        66572.550681  65439.224940
